# %%
# !nvidia-smi
# Out:
# Fri Jun 10 07:03:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    27W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -q datasets
# !pip install -q sentence-transformers
# Out:
#      |████████████████████████████████| 346 kB 15.9 MB/s
#      |████████████████████████████████| 212 kB 65.0 MB/s
#      |████████████████████████████████| 140 kB 73.1 MB/s
#      |████████████████████████████████| 1.1 MB 60.0 MB/s
#      |████████████████████████████████| 86 kB 5.5 MB/s
#      |████████████████████████████████| 86 kB 6.4 MB/s
#      |████████████████████████████████| 596 kB 68.0 MB/s
#      |████████████████████████████████| 127 kB 56.5 MB/s
#      |████████████████████████████████| 94 kB 4.0 MB/s
#      |████████████████████████████████| 271 kB 53.8 MB/s
#      |████████████████████████████████| 144 kB 61.4 MB/s
#      |████████████████████████████████| 112 kB 63.3 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
#      |████████████████████████████████| 79 kB 5.4 MB/s
#      |████████████████████████████████| 4.2 MB 36.4 MB/s
#      |████████████████████████████████| 1.2 MB 61.2 MB/s
#      |████████████████████████████████| 6.6 MB 47.3 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done

# %%
import os, sys
import random
import pickle
from pathlib import Path
from tqdm.notebook import tqdm
from typing import Dict

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from datasets import load_metric

from transformers import RobertaForMaskedLM, RobertaTokenizerFast, RobertaTokenizer
from transformers import LineByLineTextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments
from transformers.modeling_outputs import SequenceClassifierOutput

from sentence_transformers import InputExample
from sentence_transformers import models, SentenceTransformer
from sentence_transformers import losses
from sentence_transformers.util import cos_sim
from sentence_transformers.evaluation import LabelAccuracyEvaluator
from sentence_transformers.losses.TripletLoss import TripletDistanceMetric

# %%
clean_legal_corpus_df = pd.read_pickle('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/datasets/clean_legal_corpus.pkl')
clean_legal_corpus_df
# Out:
#                                                                         text
# law_id         article_id
# 01/2009/tt-bnn 1           phạm_vi áp_dụng thông_tư hướng_dẫn tuần_tra ca...
#                2           tổ_chức lực_lượng hàng trước mùa mưa_lũ uỷ_ban...
#                3           tiêu_chuẩn thành_viên lực_lượng tuần_tra canh_...
#                4           nhiệm_vụ lực_lượng tuần_tra canh_gác đê chấp_h...
#                5           phù_hiệu lực_lượng tuần_tra canh_gác đê phù_hi...
# ...                                                                      ...
# 99/2020/nđ-cp  60          thẩm_quyền xử_phạt hải_quan chi_cục trưởng chi...
#                61          thẩm_quyền xử_phạt quản_lý thị_trường kiểm_soá...
#                62          thẩm_quyền xử_phạt thanh_tra thanh_tra_viên gi...
#                63          phân_định thẩm_quyền xử_phạt chủ_tịch uỷ_ban_n...
#                64          hiệu_lực thi_hành nghị_định hiệu_lực thi_hành ...
#
# [61425 rows x 1 columns]

# %%
clean_question_answer_df = pd.read_pickle('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/datasets/clean_question_answer_df.pkl')
clean_question_answer_df
# Out:
#                            question_id  \
# 0     0637bf82c8b290c7875c5bfddbf91df5
# 1     ade2b2ee4f5b869f75f0d183902382af
# 2     8fa164edc7a8419cd7dc9ce66d8e695a
# 3     3aed91309b72097b34427dd28bebd98a
# 4     fe9131a8862ce1bfa7de7e2b30eeb39e
# ...                                ...
# 3191  bd2f979dabdf0033a00ff488b2893e12
# 3192  b7347919f2bd65a2da6f9d0b1728a51c
# 3193  bda416f28b8c88ce25604a26b01081cb
# 3194  6088765b2e502c7d900a3f9a2f82f2b4
# 3195  e3269fcc763ea92e5bab69ca67d88dd9
#
#                                                question  \
# 0          công_an xã xử_phạt lỗi mang bằng lái_xe đúng
# 1     thực_hiện thao_tác nạp mẫu bình chứa xử_lý mẫu...
# 2     trình_tự đánh_giá chất_lượng hàng đối_với kiểm...
# 3     tử_tù chết tiêm thuốc_độc thân_nhân nhận xác h...
# 4     trách_nhiệm khoa_học công_nghệ quản_lý phát_tr...
# ...                                                 ...
# 3191  nội_dung kiểm_tra công_tác nghiệm_thu công_trì...
# 3192  mức phạt đối_với hành_vi chuyển mục_đích sử_dụ...
# 3193        trích xuất thi_hành án hình_sự hiểu thế_nào
# 3194  chạy ô_tô dầu_nhờn rơi xuống_đường phạt bao_nhiêu
# 3195  tổ sát_hạch cấp giấy_phép lái tàu_hoả bao_nhiê...
#
#                                       relevant_articles
# 0     [{'law_id': '47/2011/tt-bca', 'article_id': '7'}]
# 1     [{'law_id': '41/2020/tt-bca', 'article_id': '1...
# 2     [{'law_id': '159/2020/nđ-cp', 'article_id': '1...
# 3     [{'law_id': '53/2010/qh12', 'article_id': '60'...
# 4     [{'law_id': '63/2020/nđ-cp', 'article_id': '20'}]
# ...                                                 ...
# 3191  [{'law_id': '06/2021/nđ-cp', 'article_id': '24'}]
# 3192  [{'law_id': '35/2019/nđ-cp', 'article_id': '12'}]
# 3193    [{'law_id': '41/2019/qh14', 'article_id': '3'}]
# 3194  [{'law_id': '100/2019/nđ-cp', 'article_id': '2...
# 3195  [{'law_id': '33/2018/tt-bgtvt', 'article_id': ...
#
# [3196 rows x 3 columns]

# %%
with open('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/datasets/neg_pairs_top_20_2.pkl', 'rb') as f:
    neg_pairs_top_20 = pickle.load(f)

# %%
neg_pairs_top_20[:5]
# Out:
# [{'negative': [{'article_id': '1', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '13/2012/ttlt-bca-btp-vksndtc-tandtc'},
#    {'article_id': '1', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '1', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '1', 'law_id': '13/2013/ttlt-bca-bqp-vksndtc-tandtc'},
#    {'article_id': '1', 'law_id': '123/2014/tt-btc'},
#    {'article_id': '1', 'law_id': '19/2018/tt-bnnptnt'},
#    {'article_id': '2', 'law_id': '19/2018/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '33/2015/tt-bca'},
#    {'article_id': '1', 'law_id': '04/2014/tt-blđtbxh'},
#    {'article_id': '1', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '1', 'law_id': '206/2016/tt-btc'},
#    {'article_id': '1', 'law_id': '31/2018/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '115/2013/tt-btc'},
#    {'article_id': '1', 'law_id': '05/2019/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '13/2010/tt-bvhttdl'},
#    {'article_id': '1', 'law_id': '18/2012/tt-bvhttdl'},
#    {'article_id': '1', 'law_id': '07/2019/tt-bvhttdl'}],
#   'positive': {'article_id': '1', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '32', 'law_id': '79/2014/nđ-cp'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '15', 'law_id': '66/2014/tt-bca'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '28', 'law_id': '71/2002/nđ-cp'},
#    {'article_id': '30', 'law_id': '136/2020/nđ-cp'},
#    {'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '15', 'law_id': '01/2019/nđ-cp'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'}],
#   'positive': {'article_id': '2', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '4', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '75/2018/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '06/2013/nđ-cp'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '38/2006/nđ-cp'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '9', 'law_id': '39/2018/tt-nhnn'},
#    {'article_id': '93', 'law_id': '59/2020/qh14'},
#    {'article_id': '3', 'law_id': '159/2016/nđ-cp'},
#    {'article_id': '23', 'law_id': '77/2019/tt-btc'},
#    {'article_id': '11', 'law_id': '41/2018/tt-bnnptnt'},
#    {'article_id': '31', 'law_id': '73/2016/nđ-cp'},
#    {'article_id': '3', 'law_id': '123/2014/tt-btc'},
#    {'article_id': '34', 'law_id': '136/2020/nđ-cp'}],
#   'positive': {'article_id': '3', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '7', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '01/2019/nđ-cp'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '208/2013/nđ-cp'},
#    {'article_id': '7', 'law_id': '65/2020/tt-bca'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '48', 'law_id': '18/2012/qh13'},
#    {'article_id': '25', 'law_id': '16/2020/tt-bqp'},
#    {'article_id': '4', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '9', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '9', 'law_id': '27/2010/nđ-cp'},
#    {'article_id': '45', 'law_id': '27/2001/qh10'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'}],
#   'positive': {'article_id': '4', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '7', 'law_id': '148/2016/nđ-cp'},
#    {'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '26/2017/tt-bgtvt'},
#    {'article_id': '11', 'law_id': '30/2015/tt-bnnptnt'},
#    {'article_id': '2', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '12', 'law_id': '75/2018/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '47/2016/tt-bgtvt'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '52/2015/tt-bgtvt'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '18/2015/tt-bgtvt'},
#    {'article_id': '15', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '10', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '7', 'law_id': '08/2016/tt-bca'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '5', 'law_id': '01/2009/tt-bnn'}}]

# %%
train_df, val_df = train_test_split(clean_question_answer_df, test_size=0.1, random_state=42)

# %%
val_df
# Out:
#                            question_id  \
# 1951  8e2cfe626cebf209f94e0db8f147960c
# 1204  0a32724630653580cc90c77bcf552baf
# 2661  e66ae5eecc1672bac2c5799673666bda
# 705   6b815a5b10736472101034aa8bd58146
# 1036  4d4ed6ef19708f3e18fef48e4786a06e
# ...                                ...
# 449   d3e3db3c2ac0799e4afa85e44766003b
# 1563  383d04dfac51dda6b2b7e9ebd6336052
# 605   6a3175d244fa8cd461b7b9aa227f124a
# 2630  0aa5a051629e2a3580bbb55f2fab40cb
# 3057  11e5f08c43b922d8c9138fe00d9f8d2b
#
#                                                question  \
# 1951  mức xử_phạt đối_với hành_vi tổ_chức khám sức_k...
# 1204  tranh_chấp giữa cơ_quan ký_kết hợp_đồng dự_án ...
# 2661  trình_tự cấp cấp giấy chứng_nhận đủ điều_kiện ...
# 705                thành_viên hợp danh chủ doanh_nghiệp
# 1036              luật_sư miễn đào_tạo nghề đấu_giá hay
# ...                                                 ...
# 449   trình_tự thủ_tục cấp giấy chứng_nhận thành_viê...
# 1563  hồ_sơ đề_nghị hỗ_trợ chi_phí mai_táng gồm nhữn...
# 605   quy_định giấy chứng_nhận huấn_luyện nghiệp_vụ ...
# 2630  mức phạt phối_hợp cơ_quan nhà_nước thẩm_quyền ...
# 3057  quy_định pháp_luật mục_đích đào_tạo bồi_dưỡng ...
#
#                                       relevant_articles
# 1951  [{'law_id': '28/2020/nđ-cp', 'article_id': '21'}]
# 1204   [{'law_id': '64/2020/qh14', 'article_id': '97'}]
# 2661  [{'law_id': '26/2019/nđ-cp', 'article_id': '28'}]
# 705   [{'law_id': '59/2020/qh14', 'article_id': '180'}]
# 1036   [{'law_id': '01/2016/qh14', 'article_id': '12'}]
# ...                                                 ...
# 449   [{'law_id': '155/2020/nđ-cp', 'article_id': '1...
# 1563  [{'law_id': '20/2021/nđ-cp', 'article_id': '11'}]
# 605   [{'law_id': '03/2020/tt-bgtvt', 'article_id': ...
# 2630  [{'law_id': '15/2020/nđ-cp', 'article_id': '10'}]
# 3057  [{'law_id': '204/2014/tt-btc', 'article_id': '...
#
# [320 rows x 3 columns]

# %%
train_samples = []

for anc_sent, pos_ids in train_df[['question', 'relevant_articles']].values:
    for pos_id in pos_ids:
        pos_sent = clean_legal_corpus_df.loc[pos_id['law_id'], pos_id['article_id']].text
        train_samples.append(InputExample(texts=[anc_sent, pos_sent], label=1))

        for pair in neg_pairs_top_20:
            if pos_id == pair['positive']:
                neg_ids = pair['negative']
                for neg_id in neg_ids:
                    neg_sent = clean_legal_corpus_df.loc[neg_id['law_id'], neg_id['article_id']].text
                    train_samples.append(InputExample(texts=[anc_sent, neg_sent], label=0))
                break

# %%
val_samples = []

for anc_sent, pos_ids in val_df[['question', 'relevant_articles']].values:
    for pos_id in pos_ids:
        pos_sent = clean_legal_corpus_df.loc[pos_id['law_id'], pos_id['article_id']].text
        val_samples.append(InputExample(texts=[anc_sent, pos_sent], label=1))

        for pair in neg_pairs_top_20:
            if pos_id == pair['positive']:
                neg_ids = pair['negative']
                for neg_id in neg_ids:
                    neg_sent = clean_legal_corpus_df.loc[neg_id['law_id'], neg_id['article_id']].text
                    val_samples.append(InputExample(texts=[anc_sent, neg_sent], label=0))
                break

# %%
BATCH_SIZE = 16

train_dataloader = DataLoader(train_samples, batch_size=BATCH_SIZE, shuffle=True,
                              num_workers=0, drop_last=False)

val_dataloader = DataLoader(val_samples, batch_size=BATCH_SIZE, shuffle=False,
                              num_workers=0, drop_last=False)

# %%
model = SentenceTransformer('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/checkpoints/task_training_1/')
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: RobertaModel
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )

# %%
train_loss = losses.ContrastiveLoss(model=model)

# %%
from sentence_transformers.evaluation import BinaryClassificationEvaluator

evaluator = BinaryClassificationEvaluator.from_input_examples(val_samples)

# %%
epochs = 5
warmup_steps = int(len(train_dataloader) * epochs * 0.1)

model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=epochs,
    evaluator=evaluator,
    evaluation_steps=1400,
    warmup_steps=warmup_steps,
    output_path='/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/checkpoints/task_training_2/',
    checkpoint_path='/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/checkpoints/task_training_2/',
    optimizer_params={'lr': 2e-6},
    checkpoint_save_steps=3800,
    checkpoint_save_total_limit=2,
    save_best_model=True,
    use_amp=True,
    show_progress_bar=True,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/3895 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/3895 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/3895 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/3895 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e55bf6d8f586> in <module>()
#      15     save_best_model=True,
#      16     use_amp=True,
# ---> 17     show_progress_bar=True,
#      18 )
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/SentenceTransformer.py in fit(self, train_objectives, evaluator, epochs, steps_per_epoch, scheduler, warmup_steps, optimizer_class, optimizer_params, weight_decay, evaluation_steps, output_path, save_best_model, max_grad_norm, use_amp, callback, show_progress_bar, checkpoint_path, checkpoint_save_steps, checkpoint_save_total_limit)
#     699                     if use_amp:
#     700                         with autocast():
# --> 701                             loss_value = loss_model(features, labels)
#     702
#     703                         scale_before_step = scaler.get_scale()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/losses/ContrastiveLoss.py in forward(self, sentence_features, labels)
#      61
#      62     def forward(self, sentence_features: Iterable[Dict[str, Tensor]], labels: Tensor):
# ---> 63         reps = [self.model(sentence_feature)['sentence_embedding'] for sentence_feature in sentence_features]
#      64         assert len(reps) == 2
#      65         rep_anchor, rep_other = reps
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/losses/ContrastiveLoss.py in <listcomp>(.0)
#      61
#      62     def forward(self, sentence_features: Iterable[Dict[str, Tensor]], labels: Tensor):
# ---> 63         reps = [self.model(sentence_feature)['sentence_embedding'] for sentence_feature in sentence_features]
#      64         assert len(reps) == 2
#      65         rep_anchor, rep_other = reps
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features)
#      64             trans_features['token_type_ids'] = features['token_type_ids']
#      65
# ---> 66         output_states = self.auto_model(**trans_features, return_dict=False)
#      67         output_tokens = output_states[0]
#      68
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     855             output_attentions=output_attentions,
#     856             output_hidden_states=output_hidden_states,
# --> 857             return_dict=return_dict,
#     858         )
#     859         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     528                     encoder_attention_mask,
#     529                     past_key_value,
# --> 530                     output_attentions,
#     531                 )
#     532
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     412             head_mask,
#     413             output_attentions=output_attentions,
# --> 414             past_key_value=self_attn_past_key_value,
#     415         )
#     416         attention_output = self_attention_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     341             encoder_attention_mask,
#     342             past_key_value,
# --> 343             output_attentions,
#     344         )
#     345         attention_output = self.output(self_outputs[0], hidden_states)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     198         output_attentions: Optional[bool] = False,
#     199     ) -> Tuple[torch.Tensor]:
# --> 200         mixed_query_layer = self.query(hidden_states)
#     201
#     202         # If this is instantiated as a cross-attention module, the keys
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
