# %%
# !nvidia-smi
# Out:
# Fri Jun 10 06:50:46 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -q sentence-transformers
# Out:
#      |████████████████████████████████| 79 kB 4.8 MB/s
#      |████████████████████████████████| 4.2 MB 34.6 MB/s
#      |████████████████████████████████| 1.2 MB 51.8 MB/s
#      |████████████████████████████████| 86 kB 5.2 MB/s
#      |████████████████████████████████| 596 kB 11.3 MB/s
#      |████████████████████████████████| 6.6 MB 57.2 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done

# %%
import os
import sys

import torch
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader

from sentence_transformers import SentenceTransformer, models
from sentence_transformers.datasets import DenoisingAutoEncoderDataset
from sentence_transformers.losses import DenoisingAutoEncoderLoss
from sentence_transformers import util

# %%
clean_legal_corpus_df = pd.read_pickle('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/datasets/clean_legal_corpus.pkl').reset_index()
clean_legal_corpus_df
# Out:
#                law_id article_id  \
# 0      01/2009/tt-bnn          1
# 1      01/2009/tt-bnn          2
# 2      01/2009/tt-bnn          3
# 3      01/2009/tt-bnn          4
# 4      01/2009/tt-bnn          5
# ...               ...        ...
# 61420   99/2020/nđ-cp         60
# 61421   99/2020/nđ-cp         61
# 61422   99/2020/nđ-cp         62
# 61423   99/2020/nđ-cp         63
# 61424   99/2020/nđ-cp         64
#
#                                                     text
# 0      phạm_vi áp_dụng thông_tư hướng_dẫn tuần_tra ca...
# 1      tổ_chức lực_lượng hàng trước mùa mưa_lũ uỷ_ban...
# 2      tiêu_chuẩn thành_viên lực_lượng tuần_tra canh_...
# 3      nhiệm_vụ lực_lượng tuần_tra canh_gác đê chấp_h...
# 4      phù_hiệu lực_lượng tuần_tra canh_gác đê phù_hi...
# ...                                                  ...
# 61420  thẩm_quyền xử_phạt hải_quan chi_cục trưởng chi...
# 61421  thẩm_quyền xử_phạt quản_lý thị_trường kiểm_soá...
# 61422  thẩm_quyền xử_phạt thanh_tra thanh_tra_viên gi...
# 61423  phân_định thẩm_quyền xử_phạt chủ_tịch uỷ_ban_n...
# 61424  hiệu_lực thi_hành nghị_định hiệu_lực thi_hành ...
#
# [61425 rows x 3 columns]

# %%
ids = clean_legal_corpus_df[['law_id', 'article_id']].to_dict('records')
corpus = clean_legal_corpus_df['text'].values

# %%
embedder = SentenceTransformer('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/checkpoints/task_training_1')
embedder
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: RobertaModel
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )

# %%
corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1920 [00:00<?, ?it/s]

# %%
top_k = 20
neg_pairs_top_20 = []

for i, (id, query_emb) in enumerate(zip(ids, corpus_embeddings)):
    cos_scores = util.cos_sim(query_emb, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k+1)

    # print("\n\n======================\n\n")
    # print("Query:", corpus[i])
    # print("\nTop 5 most similar sentences in corpus:")

    neg_pair = {'positive': id, 'negative': [ids[idx] for idx in top_results[1][1:]]}
    neg_pairs_top_20.append(neg_pair)

    # for score, idx in zip(top_results[0], top_results[1]):
    #     print(ids[idx], "(Score: {:.4f})".format(score))

# %%
neg_pairs_top_20[:10]
# Out:
# [{'negative': [{'article_id': '1', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '13/2012/ttlt-bca-btp-vksndtc-tandtc'},
#    {'article_id': '1', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '1', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '1', 'law_id': '13/2013/ttlt-bca-bqp-vksndtc-tandtc'},
#    {'article_id': '1', 'law_id': '123/2014/tt-btc'},
#    {'article_id': '1', 'law_id': '19/2018/tt-bnnptnt'},
#    {'article_id': '2', 'law_id': '19/2018/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '33/2015/tt-bca'},
#    {'article_id': '1', 'law_id': '04/2014/tt-blđtbxh'},
#    {'article_id': '1', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '1', 'law_id': '206/2016/tt-btc'},
#    {'article_id': '1', 'law_id': '31/2018/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '115/2013/tt-btc'},
#    {'article_id': '1', 'law_id': '05/2019/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '13/2010/tt-bvhttdl'},
#    {'article_id': '1', 'law_id': '18/2012/tt-bvhttdl'},
#    {'article_id': '1', 'law_id': '07/2019/tt-bvhttdl'}],
#   'positive': {'article_id': '1', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '32', 'law_id': '79/2014/nđ-cp'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '15', 'law_id': '66/2014/tt-bca'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '28', 'law_id': '71/2002/nđ-cp'},
#    {'article_id': '30', 'law_id': '136/2020/nđ-cp'},
#    {'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '15', 'law_id': '01/2019/nđ-cp'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'}],
#   'positive': {'article_id': '2', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '4', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '75/2018/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '06/2013/nđ-cp'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '38/2006/nđ-cp'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '9', 'law_id': '39/2018/tt-nhnn'},
#    {'article_id': '93', 'law_id': '59/2020/qh14'},
#    {'article_id': '3', 'law_id': '159/2016/nđ-cp'},
#    {'article_id': '23', 'law_id': '77/2019/tt-btc'},
#    {'article_id': '11', 'law_id': '41/2018/tt-bnnptnt'},
#    {'article_id': '31', 'law_id': '73/2016/nđ-cp'},
#    {'article_id': '3', 'law_id': '123/2014/tt-btc'},
#    {'article_id': '34', 'law_id': '136/2020/nđ-cp'}],
#   'positive': {'article_id': '3', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '7', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '01/2019/nđ-cp'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '208/2013/nđ-cp'},
#    {'article_id': '7', 'law_id': '65/2020/tt-bca'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '48', 'law_id': '18/2012/qh13'},
#    {'article_id': '25', 'law_id': '16/2020/tt-bqp'},
#    {'article_id': '4', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '9', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '9', 'law_id': '27/2010/nđ-cp'},
#    {'article_id': '45', 'law_id': '27/2001/qh10'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'}],
#   'positive': {'article_id': '4', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '7', 'law_id': '148/2016/nđ-cp'},
#    {'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '26/2017/tt-bgtvt'},
#    {'article_id': '11', 'law_id': '30/2015/tt-bnnptnt'},
#    {'article_id': '2', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '12', 'law_id': '75/2018/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '47/2016/tt-bgtvt'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '52/2015/tt-bgtvt'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '18/2015/tt-bgtvt'},
#    {'article_id': '15', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '10', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '7', 'law_id': '08/2016/tt-bca'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '5', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '36/2017/tt-btttt'},
#    {'article_id': '16', 'law_id': '12/2010/tt-bca'},
#    {'article_id': '8', 'law_id': '52/2015/tt-bgtvt'},
#    {'article_id': '8', 'law_id': '47/2011/tt-bca'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '18/2013/nđ-cp'},
#    {'article_id': '6', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '02/2015/tt-ttcp'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '58', 'law_id': '01/2014/tt-nhnn'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '33/2016/tt-bnnptnt'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '11/2016/tt-bnnptnt'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'}],
#   'positive': {'article_id': '6', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '42', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '30', 'law_id': '28/2014/tt-bct'},
#    {'article_id': '8', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '37', 'law_id': '19/2013/tt-bgtvt'},
#    {'article_id': '3', 'law_id': '28/2018/tt-bgtvt'},
#    {'article_id': '5', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '19', 'law_id': '89/2018/nđ-cp'},
#    {'article_id': '6', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '40', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '44/2014/qđ-ttg'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '33', 'law_id': '19/2013/tt-bgtvt'},
#    {'article_id': '41', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '36', 'law_id': '19/2013/tt-bgtvt'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '7', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '5', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '41', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '45', 'law_id': '01/2014/tt-nhnn'},
#    {'article_id': '10', 'law_id': '44/2014/qđ-ttg'},
#    {'article_id': '4', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '03/2020/qđ-ttg'},
#    {'article_id': '8', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '25/2019/tt-bnnptnt'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '8', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'},
#    {'article_id': '14', 'law_id': '32/2014/tt-bgtvt'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '13', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '11', 'law_id': '208/2013/nđ-cp'},
#    {'article_id': '10', 'law_id': '15/2019/tt-bqp'},
#    {'article_id': '41', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '9', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '4', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '8', 'law_id': '25/2019/tt-bnnptnt'}],
#   'positive': {'article_id': '9', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '32/2014/tt-bgtvt'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '15', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '10', 'law_id': '01/2009/tt-bnn'}}]

# %%
import pickle

with open('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/datasets/neg_pairs_top_20_2.pkl', 'wb') as f:
    pickle.dump(neg_pairs_top_20, f)

# %%
with open('/content/drive/MyDrive/NLP/Information_Retrieval/Legal_Text_Retrieval_Zalo2021/datasets/neg_pairs_top_20_2.pkl', 'rb') as f:
    test = pickle.load(f)

# %%
test[:10]
# Out:
# [{'negative': [{'article_id': '1', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '13/2012/ttlt-bca-btp-vksndtc-tandtc'},
#    {'article_id': '1', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '1', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '1', 'law_id': '13/2013/ttlt-bca-bqp-vksndtc-tandtc'},
#    {'article_id': '1', 'law_id': '123/2014/tt-btc'},
#    {'article_id': '1', 'law_id': '19/2018/tt-bnnptnt'},
#    {'article_id': '2', 'law_id': '19/2018/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '33/2015/tt-bca'},
#    {'article_id': '1', 'law_id': '04/2014/tt-blđtbxh'},
#    {'article_id': '1', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '1', 'law_id': '206/2016/tt-btc'},
#    {'article_id': '1', 'law_id': '31/2018/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '115/2013/tt-btc'},
#    {'article_id': '1', 'law_id': '05/2019/tt-bnnptnt'},
#    {'article_id': '1', 'law_id': '13/2010/tt-bvhttdl'},
#    {'article_id': '1', 'law_id': '18/2012/tt-bvhttdl'},
#    {'article_id': '1', 'law_id': '07/2019/tt-bvhttdl'}],
#   'positive': {'article_id': '1', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '32', 'law_id': '79/2014/nđ-cp'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '15', 'law_id': '66/2014/tt-bca'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '28', 'law_id': '71/2002/nđ-cp'},
#    {'article_id': '30', 'law_id': '136/2020/nđ-cp'},
#    {'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '15', 'law_id': '01/2019/nđ-cp'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'}],
#   'positive': {'article_id': '2', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '4', 'law_id': '24/2012/ttlt-blđtbxh-bnv-btc'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '75/2018/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '06/2013/nđ-cp'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '38/2006/nđ-cp'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '9', 'law_id': '39/2018/tt-nhnn'},
#    {'article_id': '93', 'law_id': '59/2020/qh14'},
#    {'article_id': '3', 'law_id': '159/2016/nđ-cp'},
#    {'article_id': '23', 'law_id': '77/2019/tt-btc'},
#    {'article_id': '11', 'law_id': '41/2018/tt-bnnptnt'},
#    {'article_id': '31', 'law_id': '73/2016/nđ-cp'},
#    {'article_id': '3', 'law_id': '123/2014/tt-btc'},
#    {'article_id': '34', 'law_id': '136/2020/nđ-cp'}],
#   'positive': {'article_id': '3', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '7', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '01/2019/nđ-cp'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '208/2013/nđ-cp'},
#    {'article_id': '7', 'law_id': '65/2020/tt-bca'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '48', 'law_id': '18/2012/qh13'},
#    {'article_id': '25', 'law_id': '16/2020/tt-bqp'},
#    {'article_id': '4', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '9', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '9', 'law_id': '27/2010/nđ-cp'},
#    {'article_id': '45', 'law_id': '27/2001/qh10'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'}],
#   'positive': {'article_id': '4', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '7', 'law_id': '148/2016/nđ-cp'},
#    {'article_id': '2', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '26/2017/tt-bgtvt'},
#    {'article_id': '11', 'law_id': '30/2015/tt-bnnptnt'},
#    {'article_id': '2', 'law_id': '54/2013/tt-bnnptnt'},
#    {'article_id': '12', 'law_id': '75/2018/nđ-cp'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '47/2016/tt-bgtvt'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '52/2015/tt-bgtvt'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '18/2015/tt-bgtvt'},
#    {'article_id': '15', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '10', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '7', 'law_id': '08/2016/tt-bca'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '5', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '36/2017/tt-btttt'},
#    {'article_id': '16', 'law_id': '12/2010/tt-bca'},
#    {'article_id': '8', 'law_id': '52/2015/tt-bgtvt'},
#    {'article_id': '8', 'law_id': '47/2011/tt-bca'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '18/2013/nđ-cp'},
#    {'article_id': '6', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '02/2015/tt-ttcp'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '58', 'law_id': '01/2014/tt-nhnn'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '33/2016/tt-bnnptnt'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '11/2016/tt-bnnptnt'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'}],
#   'positive': {'article_id': '6', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '42', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '9', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '30', 'law_id': '28/2014/tt-bct'},
#    {'article_id': '8', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '37', 'law_id': '19/2013/tt-bgtvt'},
#    {'article_id': '3', 'law_id': '28/2018/tt-bgtvt'},
#    {'article_id': '5', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '19', 'law_id': '89/2018/nđ-cp'},
#    {'article_id': '6', 'law_id': '109/2009/nđ-cp'},
#    {'article_id': '40', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '44/2014/qđ-ttg'},
#    {'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '33', 'law_id': '19/2013/tt-bgtvt'},
#    {'article_id': '41', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '36', 'law_id': '19/2013/tt-bgtvt'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '7', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '5', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '41', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '45', 'law_id': '01/2014/tt-nhnn'},
#    {'article_id': '10', 'law_id': '44/2014/qđ-ttg'},
#    {'article_id': '4', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '03/2020/qđ-ttg'},
#    {'article_id': '8', 'law_id': '113/2007/nđ-cp'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '25/2019/tt-bnnptnt'},
#    {'article_id': '7', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '8', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '10', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'},
#    {'article_id': '14', 'law_id': '32/2014/tt-bgtvt'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '7', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '04/2019/tt-bgtvt'},
#    {'article_id': '13', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '11', 'law_id': '208/2013/nđ-cp'},
#    {'article_id': '10', 'law_id': '15/2019/tt-bqp'},
#    {'article_id': '41', 'law_id': '23/2017/tt-bgtvt'},
#    {'article_id': '9', 'law_id': '58/2015/tt-bca'},
#    {'article_id': '4', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '8', 'law_id': '25/2019/tt-bnnptnt'}],
#   'positive': {'article_id': '9', 'law_id': '01/2009/tt-bnn'}},
#  {'negative': [{'article_id': '9', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '11', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '12/2014/tt-bgtvt'},
#    {'article_id': '12', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '8', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '32/2014/tt-bgtvt'},
#    {'article_id': '3', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '1', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2016/tt-bca'},
#    {'article_id': '2', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '13', 'law_id': '01/2011/tt-bca'},
#    {'article_id': '15', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '5', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '6', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '14', 'law_id': '01/2009/tt-bnn'},
#    {'article_id': '3', 'law_id': '26/2009/tt-bnn'},
#    {'article_id': '4', 'law_id': '113/2007/nđ-cp'}],
#   'positive': {'article_id': '10', 'law_id': '01/2009/tt-bnn'}}]
